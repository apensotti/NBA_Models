# %%
import sys
sys.path.insert(0, "/home/alexp/NBA_Models/src/scripts/")

# %%
import data.transform_data
from data.load_data import load_clean
import sqlite3
from sqlite3 import Error
import pandas as pd

# %%
load = load_clean("/home/alexp/NBA_Models/sqlite/db/nba_data.db")
basic_boxscores = load.basic_boxscores()
advanced_boxscores = load.advanced_boxscores()
scoring_boxscores = load.scoring_boxscores()
agg_boxscores = load.boxscore_matchups()
agg_raw_boxscores = load.agg_boxscores_raw()
players = load.players()

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Basic Boxscores

# %%
display(basic_boxscores.tail())
# Out:
#         SEASON     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 26785  2023-24  1610612764               WAS     Washington Wizards
# 26786  2023-24  1610612759               SAS      San Antonio Spurs
# 26787  2023-24  1610612741               CHI          Chicago Bulls
# 26788  2023-24  1610612760               OKC  Oklahoma City Thunder
# 26789  2023-24  1610612753               ORL          Orlando Magic
#
#           GAME_ID   GAME_DATE      MATCHUP    WL  MIN  FGM  FGA  FG_PCT  FG3M  \
# 26785  0022300543  2024-01-13    WAS @ ATL  None  120   26   52   0.500     8
# 26786  0022300548  2024-01-13  SAS vs. CHI  None    0    5   18   0.278     3
# 26787  0022300548  2024-01-13    CHI @ SAS  None    0   10   15   0.667     5
# 26788  0022300546  2024-01-13  OKC vs. ORL  None   60   19   45   0.422     3
# 26789  0022300546  2024-01-13    ORL @ OKC  None   60   13   39   0.333     3
#
#        FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# ...

# %% [markdown]
# ### Advanced Boxscores

# %%
display(advanced_boxscores.head())
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION    TEAM_CITY  \
# 0  0021300001  1610612753     Magic               ORL      Orlando
# 1  0021300001  1610612754    Pacers               IND      Indiana
# 2  0021300002  1610612748      Heat               MIA        Miami
# 3  0021300002  1610612741     Bulls               CHI      Chicago
# 4  0021300003  1610612747    Lakers               LAL  Los Angeles
#
#              MIN  E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  \
# 0  240.000000:00          84.1        92.6         101.0       103.2
# 1  240.000000:00         101.0       103.2          84.1        92.6
# 2  240.000000:00         107.3       108.1          93.9        96.9
# 3  240.000000:00          93.9        96.9         107.3       108.1
# 4  240.000000:00         109.1       117.2         103.9       105.1
#
#    E_NET_RATING  NET_RATING  AST_PCT  AST_TOV  AST_RATIO  OREB_PCT  DREB_PCT  \
# ...

# %% [markdown]
# ### Scoring Boxscores

# %%
display(scoring_boxscores.head())
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION    TEAM_CITY  \
# 0  0021300001  1610612753     Magic               ORL      Orlando
# 1  0021300001  1610612754    Pacers               IND      Indiana
# 2  0021300002  1610612748      Heat               MIA        Miami
# 3  0021300002  1610612741     Bulls               CHI      Chicago
# 4  0021300003  1610612747    Lakers               LAL  Los Angeles
#
#              MIN  PCT_FGA_2PT  PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  \
# 0  240.000000:00        0.796        0.204        0.621           0.230
# 1  240.000000:00        0.761        0.239        0.557           0.186
# 2  240.000000:00        0.722        0.278        0.486           0.168
# 3  240.000000:00        0.687        0.313        0.589           0.063
# 4  240.000000:00        0.688        0.312        0.483           0.121
#
#    PCT_PTS_3PT  PCT_PTS_FB  PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  \
# ...

# %% [markdown]
# ### Aggregated Raw Boxscores

# %%
display(agg_raw_boxscores.head())
# Out:
#     SEASON     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME     GAME_ID  \
# 0  2013-14  1610612748               MIA            Miami Heat  0021300002
# 1  2013-14  1610612741               CHI         Chicago Bulls  0021300002
# 2  2013-14  1610612746               LAC  Los Angeles Clippers  0021300003
# 3  2013-14  1610612747               LAL    Los Angeles Lakers  0021300003
# 4  2013-14  1610612753               ORL         Orlando Magic  0021300001
#
#     GAME_DATE      MATCHUP WL  MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0  2013-10-29  MIA vs. CHI  W  240   37   72   0.514    11    20    0.550
# 1  2013-10-29    CHI @ MIA  L  240   35   83   0.422     7    26    0.269
# 2  2013-10-29    LAC @ LAL  L  240   41   83   0.494     8    21    0.381
# 3  2013-10-29  LAL vs. LAC  W  240   42   93   0.452    14    29    0.483
# 4  2013-10-29    ORL @ IND  L  240   36   93   0.387     9    19    0.474
#
# ...

# %% [markdown]
# ### Aggregated Matchup Boxscores

# %%
display(agg_boxscores[agg_boxscores['TEAM_ID_home'] == 1610612740])
# Out:
#           GAME_ID  TEAM_ID_home  TEAM_ID_away SEASON_home  \
# 7      0021300011    1610612740    1610612754     2013-14
# 42     0021300055    1610612740    1610612756     2013-14
# 100    0021300143    1610612740    1610612755     2013-14
# 116    0021300169    1610612740    1610612762     2013-14
# 156    0021300214    1610612740    1610612744     2013-14
# ...           ...           ...           ...         ...
# 11778  0022300410    1610612740    1610612763     2023-24
# 11790  0022300424    1610612740    1610612762     2023-24
# 11816  0022300446    1610612740    1610612747     2023-24
# 11827  0022300461    1610612740    1610612751     2023-24
# 11859  0022300486    1610612740    1610612746     2023-24
#
#             GAME_DATE_home        TEAM_NAME_home         TEAM_NAME_away  \
# 7      2013-10-30 00:00:00  New Orleans Pelicans         Indiana Pacers
# 42     2013-11-05 00:00:00  New Orleans Pelicans           Phoenix Suns
# ...

# %% [markdown]
# ### Player Game Stats

# %%
display(players.head())
# Out:
#   SEASON_YEAR PLAYER_ID            PLAYER_NAME NICKNAME     TEAM_ID  \
# 0     2013-14    203104         Marquis Teague  Marquis  1610612751
# 1     2013-14      1713           Vince Carter    Vince  1610612742
# 2     2013-14    202705         MarShon Brooks  MarShon  1610612747
# 3     2013-14    203507  Giannis Antetokounmpo  Giannis  1610612749
# 4     2013-14      2223       Samuel Dalembert   Samuel  1610612742
#
#   TEAM_ABBREVIATION           TEAM_NAME     GAME_ID            GAME_DATE  \
# 0               BKN       Brooklyn Nets  0021301224  2014-04-16T00:00:00
# 1               DAL    Dallas Mavericks  0021301216  2014-04-16T00:00:00
# 2               LAL  Los Angeles Lakers  0021301221  2014-04-16T00:00:00
# 3               MIL     Milwaukee Bucks  0021301217  2014-04-16T00:00:00
# 4               DAL    Dallas Mavericks  0021301216  2014-04-16T00:00:00
#
#        MATCHUP WL        MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  \
# ...
