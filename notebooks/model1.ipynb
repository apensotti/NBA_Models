# %%
import sys
sys.path.insert(0, "..\scripts")

# %%
import transform_db
from transform_db import load_clean
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("display.max_columns",None)

# %%
load = load_clean("C:\\Users\\alexp\\src\\NBA_Models\\sqlite\\db\\nba_data.db")
agg_boxscores = load.boxscore_matchups()

# %%
display(agg_boxscores.tail())
# Out:
#           GAME_ID  TEAM_ID_home  TEAM_ID_away SEASON_home  \
# 11855  0022300482    1610612739    1610612764     2023-24
# 11856  0022300481    1610612751    1610612760     2023-24
# 11857  0022300483    1610612755    1610612752     2023-24
# 11858  0022300484    1610612741    1610612766     2023-24
# 11859  0022300486    1610612740    1610612746     2023-24
#
#             GAME_DATE_home        TEAM_NAME_home         TEAM_NAME_away  \
# 11855  2024-01-05 00:00:00   Cleveland Cavaliers     Washington Wizards
# 11856  2024-01-05 00:00:00         Brooklyn Nets  Oklahoma City Thunder
# 11857  2024-01-05 00:00:00    Philadelphia 76ers        New York Knicks
# 11858  2024-01-05 00:00:00         Chicago Bulls      Charlotte Hornets
# 11859  2024-01-05 00:00:00  New Orleans Pelicans            LA Clippers
#
#       MATCHUP_home TEAM_ABBREVIATION_home  HOME_GAME_home  WL_home  FG2M_home  \
# 11855  CLE vs. WAS                    CLE               1        1         25
# 11856  BKN vs. OKC                    BKN               1        1         27
# 11857  PHI vs. NYK                    PHI               1        0         27
# 11858  CHI vs. CHA                    CHI               1        1         30
# 11859  NOP vs. LAC                    NOP               1        0         21
#
#        FG2A_home  FG3M_home  FG3A_home  FTM_home  FTA_home  OREB_home  \
# 11855         44         16         33        16        23         12
# 11856         52         14         39        28        33         20
# 11857         58          6         23        20        27          8
# 11858         46         10         28        14        17          4
# 11859         63         12         29        17        23         14
#
#        DREB_home  REB_home  AST_home  STL_home  BLK_home  TOV_home  PF_home  \
# 11855         40        52        31         9         1        24       19
# 11856         31        51        25         9         3        15       24
# 11857         30        38        22         8         9        14       18
# 11858         37        41        29         7         6        15       17
# 11859         29        43        22         9         5         9       17
#
#        PTS_home  PLUS_MINUS_home  E_OFF_RATING_home  OFF_RATING_home  \
# 11855       114               24              115.0            117.5
# 11856       124                9              123.4            124.0
# 11857        92              -36               93.0             92.0
# 11858       104               13              112.5            111.8
# 11859        95              -16               97.8            101.1
#
#        E_DEF_RATING_home  DEF_RATING_home  E_NET_RATING_home  NET_RATING_home  \
# 11855               89.5             91.8               25.5             25.7
# 11856              114.4            113.9                9.0             10.1
# 11857              124.3            128.0              -31.2            -36.0
# 11858               95.5             97.8               16.9             14.0
# 11859              115.9            118.1              -18.0            -17.0
#
#        POSS_home  PIE_home  PTS_2PT_MR_home  PTS_FB_home  PTS_OFF_TOV_home  \
# 11855       97.0     0.643                2           12                18
# 11856      100.0     0.513                5           13                11
# 11857      100.0     0.366                8           16                11
# 11858       93.0     0.633               11           24                19
# 11859       94.0     0.391                3           11                17
#
#        PTS_PAINT_home  AST_2PM_home  AST_3PM_home  UAST_2PM_home  \
# 11855              47            16            15              9
# 11856              47            11            13             15
# 11857              46            16             6             10
# 11858              48            18            10             11
# 11859              38            12             9              8
#
#        UAST_3PM_home TEAM_ABBREVIATION_away  HOME_GAME_away  WL_away  \
# 11855              1                    WAS               0        0
# 11856              0                    OKC               0        0
# 11857              0                    NYK               0        1
# 11858              0                    CHA               0        0
# 11859              3                    LAC               0        1
#
#        FG2M_away  FG2A_away  FG3M_away  FG3A_away  FTM_away  FTA_away  \
# 11855         26         54          9         30        11        15
# 11856         36         53          9         31        16        24
# 11857         25         48         18         41        24        25
# 11858         26         55         10         34         9        12
# 11859         25         46         15         36        16        20
#
#        OREB_away  DREB_away  REB_away  AST_away  STL_away  BLK_away  TOV_away  \
# 11855          7         24        31        19        12         8        17
# 11856          7         29        36        29         8         5        13
# 11857         10         39        49        27         7         7        13
# 11858         12         30        42        20         7         1        13
# 11859         10         40        50        28         6         7        15
#
#        PF_away  PTS_away  PLUS_MINUS_away  E_OFF_RATING_away  OFF_RATING_away  \
# 11855       19        90              -24               89.5             91.8
# 11856       26       115               -9              114.4            113.9
# 11857       22       128               36              124.3            128.0
# 11858       20        91              -13               95.5             97.8
# 11859       18       111               16              115.9            118.1
#
#        E_DEF_RATING_away  DEF_RATING_away  E_NET_RATING_away  NET_RATING_away  \
# 11855              115.0            117.5              -25.5            -25.7
# 11856              123.4            124.0               -9.0            -10.1
# 11857               93.0             92.0               31.2             36.0
# 11858              112.5            111.8              -16.9            -14.0
# 11859               97.8            101.1               18.0             17.0
#
#        POSS_away  PIE_away  PTS_2PT_MR_away  PTS_FB_away  PTS_OFF_TOV_away  \
# 11855       98.0     0.357                1           15                28
# 11856      101.0     0.487                8           12                20
# 11857      100.0     0.634                6           33                14
# 11858       93.0     0.367               16           10                16
# 11859       94.0     0.609                9           12                 7
#
#        PTS_PAINT_away  AST_2PM_away  AST_3PM_away  UAST_2PM_away  \
# 11855              50            10             8             15
# 11856              64            20             8             15
# 11857              44            13            14             12
# 11858              36            10             9             15
# 11859              39            16            12              9
#
#        UAST_3PM_away
# 11855              0
# 11856              0
# 11857              3
# 11858              1
# 11859              3

# %% [markdown]
# ### Data Preparation

# %%
column_filter = ['GAME_DATE_home','HOME_GAME_home','TEAM_ABBREVIATION_home','WL_home', 'FG2M_home',
       'FG2A_home', 'FG3M_home', 'FG3A_home', 'FTM_home', 'FTA_home',
       'OREB_home', 'DREB_home', 'REB_home', 'AST_home', 'STL_home',
       'BLK_home', 'TOV_home', 'PF_home', 'PTS_home', 'PLUS_MINUS_home',
       'E_OFF_RATING_home', 'OFF_RATING_home', 'E_DEF_RATING_home',
       'DEF_RATING_home', 'E_NET_RATING_home', 'NET_RATING_home', 'POSS_home',
       'PIE_home', 'PTS_2PT_MR_home', 'PTS_FB_home', 'PTS_OFF_TOV_home',
       'PTS_PAINT_home', 'AST_2PM_home', 'AST_3PM_home', 'UAST_2PM_home',
       'UAST_3PM_home', 'HOME_GAME_away','TEAM_ABBREVIATION_away', 'WL_away',
       'FG2M_away', 'FG2A_away', 'FG3M_away', 'FG3A_away', 'FTM_away',
       'FTA_away', 'OREB_away', 'DREB_away', 'REB_away', 'AST_away',
       'STL_away', 'BLK_away', 'TOV_away', 'PF_away', 'PTS_away',
       'PLUS_MINUS_away', 'E_OFF_RATING_away', 'OFF_RATING_away',
       'E_DEF_RATING_away', 'DEF_RATING_away', 'E_NET_RATING_away',
       'NET_RATING_away', 'POSS_away', 'PIE_away', 'PTS_2PT_MR_away',
       'PTS_FB_away', 'PTS_OFF_TOV_away', 'PTS_PAINT_away', 'AST_2PM_away',
       'AST_3PM_away', 'UAST_2PM_away', 'UAST_3PM_away']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(agg_boxscores['TEAM_ABBREVIATION_home'])

TEAM_ID_lst = set(agg_boxscores['TEAM_ID_home'])

team_list_dfs = []
X = []
y = []

window_size = 10

for id in TEAM_ID_lst:
    gsw_df = agg_boxscores.loc[((agg_boxscores['TEAM_ID_home'] == id) | (agg_boxscores['TEAM_ID_away'] == id)) & (agg_boxscores['SEASON_home'] != '2023-24')]
    DATA_DROP = gsw_df[column_filter]

    DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
    DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])

    column_filter2 = ['HOME_GAME_home','NAME_ENC_home', 'FG2M_home',
       'FG2A_home', 'FG3M_home', 'FG3A_home', 'FTM_home', 'FTA_home',
       'OREB_home', 'DREB_home', 'REB_home', 'AST_home', 'STL_home',
       'BLK_home', 'TOV_home', 'PF_home', 'PTS_home', 'PLUS_MINUS_home',
       'E_OFF_RATING_home', 'OFF_RATING_home', 'E_DEF_RATING_home',
       'DEF_RATING_home', 'E_NET_RATING_home', 'NET_RATING_home', 'POSS_home',
       'PIE_home', 'PTS_2PT_MR_home', 'PTS_FB_home', 'PTS_OFF_TOV_home',
       'PTS_PAINT_home', 'AST_2PM_home', 'AST_3PM_home', 'UAST_2PM_home',
       'UAST_3PM_home', 'HOME_GAME_away','NAME_ENC_away',
       'FG2M_away', 'FG2A_away', 'FG3M_away', 'FG3A_away', 'FTM_away',
       'FTA_away', 'OREB_away', 'DREB_away', 'REB_away', 'AST_away',
       'STL_away', 'BLK_away', 'TOV_away', 'PF_away', 'PTS_away',
       'PLUS_MINUS_away', 'E_OFF_RATING_away', 'OFF_RATING_away',
       'E_DEF_RATING_away', 'DEF_RATING_away', 'E_NET_RATING_away',
       'NET_RATING_away', 'POSS_away', 'PIE_away', 'PTS_2PT_MR_away',
       'PTS_FB_away', 'PTS_OFF_TOV_away', 'PTS_PAINT_away', 'AST_2PM_away',
       'AST_3PM_away', 'UAST_2PM_away', 'UAST_3PM_away'] 
    DATA = DATA_DROP[column_filter2]
    LABEL = DATA_DROP['WL_home']
    DATA_np = DATA.to_numpy()
    LABEL_np = LABEL.to_numpy()
    for i in range(len(DATA_np)-window_size):        
      row = [a for a in DATA_np[i:i+window_size]]
      X.append(row)
      label = LABEL_np[i+window_size]
      y.append(label)

      X = np.array(X)
      y = np.array(y)
# Out:
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\3634417163.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])

# %%
DATA_DROP = agg_boxscores[column_filter]

DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])

X2 = []
y2 = []

column_filter2 = ['HOME_GAME_home','NAME_ENC_home', 'FG2M_home',
   'FG2A_home', 'FG3M_home', 'FG3A_home', 'FTM_home', 'FTA_home',
   'OREB_home', 'DREB_home', 'REB_home', 'AST_home', 'STL_home',
   'BLK_home', 'TOV_home', 'PF_home', 'PTS_home', 'PLUS_MINUS_home',
   'E_OFF_RATING_home', 'OFF_RATING_home', 'E_DEF_RATING_home',
   'DEF_RATING_home', 'E_NET_RATING_home', 'NET_RATING_home', 'POSS_home',
   'PIE_home', 'PTS_2PT_MR_home', 'PTS_FB_home', 'PTS_OFF_TOV_home',
   'PTS_PAINT_home', 'AST_2PM_home', 'AST_3PM_home', 'UAST_2PM_home',
   'UAST_3PM_home', 'HOME_GAME_away','NAME_ENC_away',
   'FG2M_away', 'FG2A_away', 'FG3M_away', 'FG3A_away', 'FTM_away',
   'FTA_away', 'OREB_away', 'DREB_away', 'REB_away', 'AST_away',
   'STL_away', 'BLK_away', 'TOV_away', 'PF_away', 'PTS_away',
   'PLUS_MINUS_away', 'E_OFF_RATING_away', 'OFF_RATING_away',
   'E_DEF_RATING_away', 'DEF_RATING_away', 'E_NET_RATING_away',
   'NET_RATING_away', 'POSS_away', 'PIE_away', 'PTS_2PT_MR_away',
   'PTS_FB_away', 'PTS_OFF_TOV_away', 'PTS_PAINT_away', 'AST_2PM_away',
   'AST_3PM_away', 'UAST_2PM_away', 'UAST_3PM_away'] 

DATA = DATA_DROP[column_filter2]
LABEL = DATA_DROP['WL_home']
DATA_np = DATA.to_numpy()
LABEL_np = LABEL.to_numpy()
for i in range(len(DATA_np)-window_size):        
  row = [a for a in DATA_np[i:i+window_size]]
  X2.append(row)
  label = LABEL_np[i+window_size]
  y2.append(label)

X2 = np.array(X2)
y2 = np.array(y2)
# Out:
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\2553213591.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_home'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_home'])
# C:\Users\alexp\AppData\Local\Temp\ipykernel_3380\2553213591.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DATA_DROP['NAME_ENC_away'] = encoder.transform(DATA_DROP['TEAM_ABBREVIATION_away'])

# %%
X2.shape
# Out:
# (11830, 30, 68)

# %%
X_train, y_train = X2[:8000], y2[:8000]
X_val, y_val = X2[8000:10000], y2[8000:10000]
X_test, y_test = X2[10000:], y2[10000:]
X_train.shape, y_train.shape
# Out:
# ((8000, 30, 68), (8000,))

# %%
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, LSTM, Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError, Accuracy
from tensorflow.keras.optimizers import Adam

model1 = Sequential()

model1.add(InputLayer((30,68)))
model1.add(LSTM(256))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1,'sigmoid'))

model1.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_26 (LSTM)              (None, 256)               332800
#
#  dense_39 (Dense)            (None, 8)                 2056
#
#  dense_40 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 334865 (1.28 MB)
# Trainable params: 334865 (1.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.backend.clear_session()

# %%
cp = ModelCheckpoint("src/models/model1", save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=.0001), metrics=[RootMeanSquaredError()])

# %%
with tf.device('/GPU:0'):
    model1.fit(X_train,y_train,validation_data=(X_val,y_val), epochs=1000, callbacks=[cp])
# Out:
# Epoch 1/1000
# 248/250 [============================>.] - ETA: 0s - loss: 0.2465 - root_mean_squared_error: 0.4965INFO:tensorflow:Assets written to: src/models\model1\assets
# INFO:tensorflow:Assets written to: src/models\model1\assets
# 250/250 [==============================] - 7s 24ms/step - loss: 0.2465 - root_mean_squared_error: 0.4965 - val_loss: 0.2494 - val_root_mean_squared_error: 0.4994
# Epoch 2/1000
# 250/250 [==============================] - ETA: 0s - loss: 0.2448 - root_mean_squared_error: 0.4948INFO:tensorflow:Assets written to: src/models\model1\assets
# INFO:tensorflow:Assets written to: src/models\model1\assets
# 250/250 [==============================] - 5s 22ms/step - loss: 0.2448 - root_mean_squared_error: 0.4948 - val_loss: 0.2474 - val_root_mean_squared_error: 0.4974
# Epoch 3/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2445 - root_mean_squared_error: 0.4944 - val_loss: 0.2497 - val_root_mean_squared_error: 0.4997
# Epoch 4/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2444 - root_mean_squared_error: 0.4943 - val_loss: 0.2481 - val_root_mean_squared_error: 0.4981
# Epoch 5/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2447 - root_mean_squared_error: 0.4947 - val_loss: 0.2481 - val_root_mean_squared_error: 0.4981
# Epoch 6/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2441 - root_mean_squared_error: 0.4941 - val_loss: 0.2480 - val_root_mean_squared_error: 0.4980
# Epoch 7/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2442 - root_mean_squared_error: 0.4942 - val_loss: 0.2494 - val_root_mean_squared_error: 0.4994
# Epoch 8/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2443 - root_mean_squared_error: 0.4943 - val_loss: 0.2499 - val_root_mean_squared_error: 0.4999
# Epoch 9/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2443 - root_mean_squared_error: 0.4943 - val_loss: 0.2489 - val_root_mean_squared_error: 0.4989
# Epoch 10/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2441 - root_mean_squared_error: 0.4941 - val_loss: 0.2486 - val_root_mean_squared_error: 0.4986
# Epoch 11/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2439 - root_mean_squared_error: 0.4939 - val_loss: 0.2485 - val_root_mean_squared_error: 0.4985
# Epoch 12/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2440 - root_mean_squared_error: 0.4939 - val_loss: 0.2486 - val_root_mean_squared_error: 0.4986
# Epoch 13/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2441 - root_mean_squared_error: 0.4941 - val_loss: 0.2490 - val_root_mean_squared_error: 0.4990
# Epoch 14/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2442 - root_mean_squared_error: 0.4941 - val_loss: 0.2484 - val_root_mean_squared_error: 0.4984
# Epoch 15/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2439 - root_mean_squared_error: 0.4938 - val_loss: 0.2484 - val_root_mean_squared_error: 0.4984
# Epoch 16/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2440 - root_mean_squared_error: 0.4939 - val_loss: 0.2493 - val_root_mean_squared_error: 0.4993
# Epoch 17/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2438 - root_mean_squared_error: 0.4937 - val_loss: 0.2490 - val_root_mean_squared_error: 0.4990
# Epoch 18/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2439 - root_mean_squared_error: 0.4939 - val_loss: 0.2482 - val_root_mean_squared_error: 0.4982
# Epoch 19/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2440 - root_mean_squared_error: 0.4939 - val_loss: 0.2497 - val_root_mean_squared_error: 0.4997
# Epoch 20/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2438 - root_mean_squared_error: 0.4937 - val_loss: 0.2493 - val_root_mean_squared_error: 0.4993
# Epoch 21/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2434 - root_mean_squared_error: 0.4933 - val_loss: 0.2505 - val_root_mean_squared_error: 0.5005
# Epoch 22/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2439 - root_mean_squared_error: 0.4939 - val_loss: 0.2487 - val_root_mean_squared_error: 0.4987
# Epoch 23/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2436 - root_mean_squared_error: 0.4936 - val_loss: 0.2508 - val_root_mean_squared_error: 0.5008
# Epoch 24/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2437 - root_mean_squared_error: 0.4937 - val_loss: 0.2488 - val_root_mean_squared_error: 0.4988
# Epoch 25/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2434 - root_mean_squared_error: 0.4934 - val_loss: 0.2491 - val_root_mean_squared_error: 0.4991
# Epoch 26/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2433 - root_mean_squared_error: 0.4933 - val_loss: 0.2494 - val_root_mean_squared_error: 0.4994
# Epoch 27/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2433 - root_mean_squared_error: 0.4933 - val_loss: 0.2490 - val_root_mean_squared_error: 0.4990
# Epoch 28/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2432 - root_mean_squared_error: 0.4932 - val_loss: 0.2497 - val_root_mean_squared_error: 0.4997
# Epoch 29/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2432 - root_mean_squared_error: 0.4931 - val_loss: 0.2504 - val_root_mean_squared_error: 0.5004
# Epoch 30/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2431 - root_mean_squared_error: 0.4931 - val_loss: 0.2488 - val_root_mean_squared_error: 0.4988
# Epoch 31/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2428 - root_mean_squared_error: 0.4928 - val_loss: 0.2495 - val_root_mean_squared_error: 0.4995
# Epoch 32/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2425 - root_mean_squared_error: 0.4925 - val_loss: 0.2506 - val_root_mean_squared_error: 0.5006
# Epoch 33/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2424 - root_mean_squared_error: 0.4924 - val_loss: 0.2496 - val_root_mean_squared_error: 0.4996
# Epoch 34/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2424 - root_mean_squared_error: 0.4924 - val_loss: 0.2488 - val_root_mean_squared_error: 0.4988
# Epoch 35/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2423 - root_mean_squared_error: 0.4922 - val_loss: 0.2492 - val_root_mean_squared_error: 0.4992
# Epoch 36/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2423 - root_mean_squared_error: 0.4923 - val_loss: 0.2496 - val_root_mean_squared_error: 0.4996
# Epoch 37/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2422 - root_mean_squared_error: 0.4921 - val_loss: 0.2499 - val_root_mean_squared_error: 0.4999
# Epoch 38/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2421 - root_mean_squared_error: 0.4920 - val_loss: 0.2503 - val_root_mean_squared_error: 0.5003
# Epoch 39/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2423 - root_mean_squared_error: 0.4922 - val_loss: 0.2502 - val_root_mean_squared_error: 0.5002
# Epoch 40/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2420 - root_mean_squared_error: 0.4919 - val_loss: 0.2496 - val_root_mean_squared_error: 0.4996
# Epoch 41/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2418 - root_mean_squared_error: 0.4918 - val_loss: 0.2498 - val_root_mean_squared_error: 0.4998
# Epoch 42/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2418 - root_mean_squared_error: 0.4917 - val_loss: 0.2505 - val_root_mean_squared_error: 0.5005
# Epoch 43/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2419 - root_mean_squared_error: 0.4918 - val_loss: 0.2499 - val_root_mean_squared_error: 0.4999
# Epoch 44/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2417 - root_mean_squared_error: 0.4917 - val_loss: 0.2513 - val_root_mean_squared_error: 0.5013
# Epoch 45/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2414 - root_mean_squared_error: 0.4914 - val_loss: 0.2513 - val_root_mean_squared_error: 0.5013
# Epoch 46/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2417 - root_mean_squared_error: 0.4917 - val_loss: 0.2508 - val_root_mean_squared_error: 0.5008
# Epoch 47/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2417 - root_mean_squared_error: 0.4916 - val_loss: 0.2506 - val_root_mean_squared_error: 0.5006
# Epoch 48/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2411 - root_mean_squared_error: 0.4910 - val_loss: 0.2496 - val_root_mean_squared_error: 0.4996
# Epoch 49/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2410 - root_mean_squared_error: 0.4909 - val_loss: 0.2526 - val_root_mean_squared_error: 0.5026
# Epoch 50/1000
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2410 - root_mean_squared_error: 0.4909 - val_loss: 0.2513 - val_root_mean_squared_error: 0.5013
# Epoch 51/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2410 - root_mean_squared_error: 0.4909 - val_loss: 0.2506 - val_root_mean_squared_error: 0.5006
# Epoch 52/1000
# 250/250 [==============================] - 4s 16ms/step - loss: 0.2410 - root_mean_squared_error: 0.4910 - val_loss: 0.2512 - val_root_mean_squared_error: 0.5012
# Epoch 53/1000
#  17/250 [=>............................] - ETA: 3s - loss: 0.2319 - root_mean_squared_error: 0.4815

# %%
model1.predict(X_test)
# Out:
# 58/58 [==============================] - 1s 6ms/step
# array([[0.27236444],
#        [0.7326065 ],
#        [0.5513759 ],
#        ...,
#        [0.638407  ],
#        [0.63792914],
#        [0.66649187]], dtype=float32)
